# %% [markdown]
# ### 데이터 전처리

# %%
# 구글 드라이브 가져오기
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
# 필요한 패지 가져오기
import pandas as pd
import numpy as np

# %%
# 데이터 불러오기
healthcare = '/content/drive/MyDrive/4조_헬스케어/자료파일/healthcare_total.csv'
df = pd.read_csv(healthcare)

# %% [markdown]
# 데이터 확인 확인 후  전처리

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.columns
# Out:
# Index(['기준년도', '가입자 일련번호', '진료내역일련번호', '성별코드', '연령대코드', '시도코드', '요양개시일자',
#        '서식코드', '진료과목코드', '주상병코드', '부상병코드', '요양일수', '입내원일수', '심결가산율',
#        '심결요양급여비용총액', '심결본인부담금', '심결보험자부담금', '총처방일수', '데이터 기준일자'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13178345 entries, 0 to 13178344
# Data columns (total 19 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   기준년도        int64
#  1   가입자 일련번호    int64
#  2   진료내역일련번호    int64
#  3   성별코드        int64
#  4   연령대코드       int64
#  5   시도코드        int64
#  6   요양개시일자      int64
#  7   서식코드        int64
#  8   진료과목코드      int64
#  9   주상병코드       object
#  10  부상병코드       object
#  11  요양일수        int64
#  12  입내원일수       int64
#  13  심결가산율       float64
#  14  심결요양급여비용총액  int64
#  15  심결본인부담금     int64
#  16  심결보험자부담금    int64
#  17  총처방일수       int64
#  18  데이터 기준일자    int64
# dtypes: float64(1), int64(16), object(2)
# memory usage: 1.9+ GB

# %%
# 결측치 확인 
df.isnull().sum()
# Out:
# 기준년도          0
# 가입자 일련번호      0
# 진료내역일련번호      0
# 성별코드          0
# 연령대코드         0
# 시도코드          0
# 요양개시일자        0
# 서식코드          0
# 진료과목코드        0
# 주상병코드         0
# 부상병코드         0
# 요양일수          0
# 입내원일수         0
# 심결가산율         0
# 심결요양급여비용총액    0
# 심결본인부담금       0
# 심결보험자부담금      0
# 총처방일수         0
# 데이터 기준일자      0
# dtype: int64

# %% [markdown]
# - 필요없는 행 삭제하기

# %%
df = df.drop('데이터 기준일자', axis = 1)
df.tail(3)
# Out:
#           기준년도  가입자 일련번호   진료내역일련번호  성별코드  ...  심결요양급여비용총액  심결본인부담금  심결보험자부담금  총처방일수
# 13178342  2019   1000000  110172739     2  ...       31890     3100     28790      0
# 13178343  2019   1000000  110819612     2  ...     1757040    27670   1729370      0
# 13178344  2019   1000000  103674218     2  ...       12610      600     12010      3
#
# [3 rows x 18 columns]

# %%
# 필요없는 열 삭제 
df = df[['가입자 일련번호', '시도코드', '연령대코드', '서식코드', '주상병코드', '부상병코드', '심결가산율']]
df.head(3)
# Out:
#    가입자 일련번호  시도코드  연령대코드  서식코드  주상병코드  부상병코드  심결가산율
# 0         1    46     12     3   M751   M750   0.25
# 1         1    46     12     3  E1164   N308   0.25
# 2         1    46     12     3   N308  E1164   0.25

# %% [markdown]
# 데이터 전처리
#   - 의료기관 종별 데이터
#     - 상급종합병원 (30%)
#     - 종합병원 (25%)
#     - 병원(20%)
#     - 의원(15%)

# %%
# 값이 0인 데이터 삭제 
df = df[df.심결가산율 != 0]

# %%
df['심결가산율'].unique()
# Out:
# array([0.25, 0.15, 0.2 , 0.3 ])

# %%
# 데이터 저장
df.to_csv('healthcare.csv')
